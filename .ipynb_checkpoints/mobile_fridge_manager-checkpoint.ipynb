# %%
#https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/cnn_archs.ipynb

# %%
from fastai.vision.all import *

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#source = f'/home/oem/Images/dataset_fridge'
source = r'C:\Users\Remi\Pictures\DATASET-20210121T074943Z-001\DATASET'

df_marks = pd.DataFrame({'fname':['p0'], 'label':['oeuf'], 'is_valid':[True]})

#os.chdir(source)
for root, dirs, files in os.walk(source, topdown = False):
   for name in files:
      my_path = os.path.join(source, root, name)
      categorie = root.split("\\")[7]
      #print(my_path)
      is_valid = False
      if r'\003\frigo' in root:
        is_valid = True
      new_row = {'fname':my_path[9+14:], 'label':categorie, 'is_valid':is_valid}
      df_marks = df_marks.append(new_row, ignore_index=True)
df_marks = df_marks[2:]

print(df_marks)
# Out:
#                                                                                                                                    fname  \
# 2                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3155250006238_PHOTOSITE_20200331_052142_0.jpg
# 3                                                        DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3228021000084-4.jpg
# 4                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3245390221698_PHOTOSITE_20180619_161421_0.jpg
# 5                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3270190020288_PHOTOSITE_20200204_175146_0.jpg
# 6    DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\5674-2-beurre-doux-gastronomique-en-plaquette-president-250-g-16304.jpg
# ..                                                                                                                                   ...
# 863                                                  DATASET-20210121T074943Z-001\DATASET\viandes\thon\002\table\IMG-20210120-WA0109.jpg
# 864                                                  DATASET-20210121T074943Z-001\DATASET\viandes\thon\002\table\IMG-20210120-WA0110.jpg
# 865                                                  DATASET-20210121T074943Z-001\DATASET\viandes\thon\002\table\IMG-20210120-WA0116.jpg
# 866                                                  DATASET-20210121T074943Z-001\DATASET\viandes\thon\002\table\IMG-20210120-WA0117.jpg
# 867                                                  DATASET-20210121T074943Z-001\DATASET\viandes\thon\002\table\IMG-20210120-WA0118.jpg
#
#       label  is_valid
# 2    beurre     False
# 3    beurre     False
# 4    beurre     False
# 5    beurre     False
# 6    beurre     False
# ..      ...       ...
# 863    thon     False
# 864    thon     False
# 865    thon     False
# 866    thon     False
# 867    thon     False
#
# [866 rows x 3 columns]

# %% [markdown]
# len("Remi\Pictures")

# %%
top_10_list = [str(x) for x in df_marks.groupby('label').agg([ 'count']).reset_index().sort_values([('fname', 'count')], ascending=False)['label'][0:5]]

# %%
df_marks = pd.DataFrame({'fname':['p0'], 'label':['oeuf'], 'is_valid':[True]})

#os.chdir(source)
for root, dirs, files in os.walk(source, topdown = False):
   for name in files:
      my_path = os.path.join(source, root, name)
      categorie = root.split("\\")[7]
      #print(my_path)
      is_valid = False
      if r'\003\frigo' in root:
        is_valid = True
      if r'\002\frigo' in root:
        is_valid = True
      if categorie in top_10_list:
          new_row = {'fname':my_path[9+14:], 'label':categorie.replace(" ","-"), 'is_valid':is_valid}
          df_marks = df_marks.append(new_row, ignore_index=True)
df_marks = df_marks[2:]

print(df_marks)
# Out:
#                                                                                                                                    fname  \
# 2                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3155250006238_PHOTOSITE_20200331_052142_0.jpg
# 3                                                        DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3228021000084-4.jpg
# 4                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3245390221698_PHOTOSITE_20180619_161421_0.jpg
# 5                              DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\3270190020288_PHOTOSITE_20200204_175146_0.jpg
# 6    DATASET-20210121T074943Z-001\DATASET\autres\beurre\internet\5674-2-beurre-doux-gastronomique-en-plaquette-president-250-g-16304.jpg
# ..                                                                                                                                   ...
# 346                                     DATASET-20210121T074943Z-001\DATASET\viandes\oeufs\telephone\supermarche\IMG_20201228_145412.jpg
# 347                                     DATASET-20210121T074943Z-001\DATASET\viandes\oeufs\telephone\supermarche\IMG_20201228_145416.jpg
# 348                                     DATASET-20210121T074943Z-001\DATASET\viandes\oeufs\telephone\supermarche\IMG_20201228_145437.jpg
# 349                                     DATASET-20210121T074943Z-001\DATASET\viandes\oeufs\telephone\supermarche\IMG_20201228_145440.jpg
# 350                                     DATASET-20210121T074943Z-001\DATASET\viandes\oeufs\telephone\supermarche\IMG_20201228_145444.jpg
#
#       label  is_valid
# 2    beurre     False
# 3    beurre     False
# 4    beurre     False
# 5    beurre     False
# 6    beurre     False
# ..      ...       ...
# 346   oeufs     False
# 347   oeufs     False
# 348   oeufs     False
# 349   oeufs     False
# 350   oeufs     False
#
# [349 rows x 3 columns]

# %%
#dls = ImageDataLoaders.from_df(df, path, folder='train', valid_col='is_valid', label_delim=' ',item_tfms=Resize(128), bs=4 ,batch_tfms=aug_transforms(size=128))
dls = ImageDataLoaders.from_df(df_marks[2:],path = r'C:\Users\Remi\Pictures', valid_col='is_valid', label_delim=' ',
                               item_tfms=Resize(256), bs=4, num_workers=0, batch_tfms=aug_transforms(size=128*1))#,do_flip=False))

# %%
dls.show_batch(unique=True,figsize=(14,14))

# %%
len(dls.train)
# Out:
# 76

# %%
len(dls.valid)
# Out:
# 11

# %%
#list(df_marks['label'])

# %%
#df_marks.loc[df_marks['is_valid']==True]

# %%
#learn = cnn_learner(dls, resnet50, metrics=partial(accuracy_multi, thresh=0.5))
#df_marks

# %%
from torchvision import models

# %%
#learn = cnn_learner(dls, mansnet_fn, cut=-1, metrics=partial(accuracy_multi, thresh=0.5))
#learn = cnn_learner(dls, models.mobilenet_v2, cut=-1, pretrained=True,metrics=partial(accuracy_multi, thresh=0.5),cbs=[SaveModelCallback()])
learn = cnn_learner(dls, resnet18, pretrained=True,metrics=partial(accuracy_multi, thresh=0.5),cbs=[SaveModelCallback()])

# %%
#learn.lr_find()
learn.path
# Out:
# Path('C:/Users/Remi/Pictures')

# %%
if False:
    import cProfile
    Pr=cProfile.Profile()
    Pr.enable()

    learn.lr_find()

    Pr.disable()
    Pr.print_stats('time')

# %%
#learn.fit_one_cycle(2, lr_max=slice(0.05))
learn.fine_tune(
    epochs=5,
    base_lr=0.05/100,
    freeze_epochs=3,
    lr_mult=100,
    pct_start=0.3,
    div=5.0,
    div_final=100000.0,
    wd=None,
    moms=None,
    cbs=None,
    reset_opt=F)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.000760</td>
#       <td>0.934136</td>
#       <td>0.531707</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.898011</td>
#       <td>0.981256</td>
#       <td>0.546341</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.804692</td>
#       <td>0.735755</td>
#       <td>0.639024</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.934136152267456.
# Better model found at epoch 2 with valid_loss value: 0.7357550859451294.
# C:\Users\Remi\miniconda3\envs\fastai\lib\site-packages\fastai\learner.py:54: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.712635</td>
#       <td>0.670972</td>
#       <td>0.678049</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.697129</td>
#       <td>0.596161</td>
#       <td>0.731707</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.599464</td>
#       <td>0.601238</td>
#       <td>0.726829</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.628047</td>
#       <td>0.613985</td>
#       <td>0.731707</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.575286</td>
#       <td>0.553045</td>
#       <td>0.756097</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6709718108177185.
# Better model found at epoch 1 with valid_loss value: 0.5961612462997437.
# Better model found at epoch 4 with valid_loss value: 0.5530453324317932.

# %%
learn.unfreeze()
learn.fit_one_cycle(5, lr_max=slice(0.001))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.502811</td>
#       <td>0.775851</td>
#       <td>0.834146</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.537258</td>
#       <td>0.784451</td>
#       <td>0.839024</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.419050</td>
#       <td>0.622116</td>
#       <td>0.839024</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348415</td>
#       <td>0.611077</td>
#       <td>0.858537</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.302001</td>
#       <td>0.621579</td>
#       <td>0.848780</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7758506536483765.
# Better model found at epoch 2 with valid_loss value: 0.6221164464950562.
# Better model found at epoch 3 with valid_loss value: 0.6110770106315613.

# %%
learn.show_results()

# %%
#learn.load(r'C:\Users\Remi\Pictures\models\model')
learn.show_results()

# %%
learn.predict(r'C:\Users\Remi\Pictures\DATASET-20210121T074943Z-001\DATASET\autres\fromage rapé\002\frigo\IMG_20210109_141927.jpg')
# Out:
# ((#1) ['fromage-rapé'],
#  TensorImage([False, False,  True, False, False]),
#  TensorImage([1.6106e-03, 1.7453e-05, 7.9644e-01, 1.1700e-08, 6.5977e-02]))

# %%
learn.predict('/home/oem/Images/dataset_fridge/Dataset/Le beurre et l_argent du beurre /internet/beurre-bordier-demi-sel.jpg')

# %%
learn.dls.vocab

# %%
learn.
